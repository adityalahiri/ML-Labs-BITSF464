# %%
import pandas as pd

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt

from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import AdaBoostClassifier

from sklearn.tree import DecisionTreeClassifier
from sklearn.linear_model import LogisticRegression

from xgboost import XGBClassifier

from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv('Income_Train.csv')
test  = pd.read_csv('Income_Test.csv')

# %%
df.describe()
# Out:
#              Sr.No.           age        fnlwgt  educational-num  \
# count  39073.000000  39073.000000  3.907300e+04     39073.000000
# mean   24387.500166     38.633379  1.895564e+05        10.085353
# std    14111.135584     13.705528  1.055786e+05         2.573959
# min        0.000000     17.000000  1.376900e+04         1.000000
# 25%    12094.000000     28.000000  1.175090e+05         9.000000
# 50%    24386.000000     37.000000  1.779550e+05        10.000000
# 75%    36627.000000     48.000000  2.369900e+05        12.000000
# max    48839.000000     90.000000  1.490400e+06        16.000000
#
#        capital-gain  capital-loss  hours-per-week  Unnamed: 15
# count  39073.000000  39073.000000    39073.000000          0.0
# mean    1133.790955     87.251606       40.390269          NaN
# std     7770.463461    403.025278       12.365225          NaN
# min        0.000000      0.000000        1.000000          NaN
# 25%        0.000000      0.000000       40.000000          NaN
# 50%        0.000000      0.000000       40.000000          NaN
# 75%        0.000000      0.000000       45.000000          NaN
# max    99999.000000   4356.000000       99.000000          NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39073 entries, 0 to 39072
# Data columns (total 17 columns):
# Sr.No.             39073 non-null int64
# age                39073 non-null int64
# workclass          39073 non-null object
# fnlwgt             39073 non-null int64
# education          39073 non-null object
# educational-num    39073 non-null int64
# marital-status     39073 non-null object
# occupation         39073 non-null object
# relationship       39073 non-null object
# race               39073 non-null object
# gender             39073 non-null object
# capital-gain       39073 non-null int64
# capital-loss       39073 non-null int64
# hours-per-week     39073 non-null int64
# native-country     39073 non-null object
# Unnamed: 15        0 non-null float64
# Prediction         39073 non-null bool
# dtypes: bool(1), float64(1), int64(7), object(8)
# memory usage: 4.8+ MB

# %%
df.drop(['Unnamed: 15'],axis=1,inplace=True)

# %%
df.head()
# Out:
#    Sr.No.  age workclass  fnlwgt     education  educational-num  \
# 0   42575   27   Private  134566       HS-grad                9
# 1    2531   20         ?  175431  Some-college               10
# 2   42008   18   Private   57108          11th                7
# 3   21107   20   Private  147171  Some-college               10
# 4   28313   47   Private  102771       7th-8th                4
#
#        marital-status         occupation   relationship                race  \
# 0       Never-married       Adm-clerical  Not-in-family               White
# 1       Never-married                  ?      Own-child               White
# 2       Never-married              Sales      Own-child               White
# 3       Never-married       Adm-clerical      Unmarried  Asian-Pac-Islander
# 4  Married-civ-spouse  Handlers-cleaners        Husband               White
#
#    gender  capital-gain  capital-loss  hours-per-week native-country  \
# 0    Male             0             0              40  United-States
# 1    Male             0             0              40  United-States
# 2    Male             0             0              16  United-States
# 3  Female             0             0              40        Vietnam
# 4    Male             0             0              40       Portugal
#
#    Prediction
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False

# %%
test.head()
# Out:
#    Sr.No.  age         workclass  fnlwgt     education  educational-num  \
# 0   23509   18           Private  260801       HS-grad                9
# 1   38928   36      Self-emp-inc  183898     Bachelors               13
# 2   23796   29           Private  209934       5th-6th                3
# 3   31209   32           Private  263908     Bachelors               13
# 4   37938   69  Self-emp-not-inc  204645  Some-college               10
#
#        marital-status         occupation   relationship   race gender  \
# 0       Never-married  Handlers-cleaners      Own-child  White   Male
# 1            Divorced              Sales  Not-in-family  White   Male
# 2  Married-civ-spouse      Other-service        Husband  White   Male
# 3  Married-civ-spouse     Prof-specialty        Husband  White   Male
# 4  Married-civ-spouse       Craft-repair        Husband  White   Male
#
#    capital-gain  capital-loss  hours-per-week native-country
# 0             0             0              20  United-States
# 1             0             0              60  United-States
# 2             0             0              40         Mexico
# 3             0             0              40  United-States
# 4          9386             0              72  United-States

# %%
categorical = ['workclass','marital-status','education','race', 'gender','native-country','occupation','relationship']

# %%
from sklearn.preprocessing import LabelEncoder


le = LabelEncoder()
for col in categorical:
    
    le.fit(df[col])
    df[col] = le.transform(df[col])
    test[col] = le.transform(test[col])

# %%
len(df)
# Out:
# 39073

# %%
len(df[df['Prediction']==False])
# Out:
# 29696

# %%
X = df.drop(['Prediction'],axis = 1)

# %%
y = df['Prediction']

# %%
test
# Out:
#       Sr.No.  age  workclass  fnlwgt  education  educational-num  \
# 0      23509   18          4  260801         11                9
# 1      38928   36          5  183898          9               13
# 2      23796   29          4  209934          4                3
# 3      31209   32          4  263908          9               13
# 4      37938   69          6  204645         15               10
# 5      46330   56          1  187873         12               14
# 6      31812   47          4  265275         15               10
# 7      29778   58          4  343957          9               13
# 8      27171   23          4  289982         11                9
# 9      42282   59          6  247552         11                9
# 10     48759   21          4  182117          7               12
# 11     35835   30          4  323069          9               13
# 12     32756   39          4  248694         11                9
# 13     48499   37          4  186009         11                9
# 14     25992   48          4  102938          9               13
# 15     32463   56          4  145574         11                9
# 16     11849   27          4  110663         11                9
# 17     29589   45          4   88500         15               10
# 18     35050   30          1   76313         11                9
# 19     16308   54          0  180211         15               10
# 20      6372   33          4  460408          9               13
# 21     15100   31          4  274818         15               10
# 22     28380   38          4  269323         11                9
# 23      3190   37          2  347136         15               10
# 24      7058   25          4  201481          9               13
# 25      2861   25          4   54298         11                9
# 26     21466   21          4  206861         15               10
# 27     39004   34          4  203488          9               13
# 28     15318   17          4  160029          1                7
# 29     43617   26          6  118523         11                9
# ...      ...  ...        ...     ...        ...              ...
# 9739   23905   43          1  203637          9               13
# 9740     585   21          4  448026         15               10
# 9741   35867   28          4  163320         11                9
# 9742    6902   30          4  415266         11                9
# 9743   45525   38          4   60313         11                9
# 9744   11213   37          4   81965         15               10
# 9745   25686   45          2  175958          6                5
# 9746   37584   34          4  111746         11                9
# 9747    9241   44          1   55363          9               13
# 9748   17348   36          4   29984          2                8
# 9749    6030   26          4  219199         11                9
# 9750    1411   59          4  193375         12               14
# 9751   33716   69          6   29980          5                4
# 9752   20440   25          4  306666         15               10
# 9753   23935   38          1  122493          9               13
# 9754   19027   57          4  296152         15               10
# 9755   10681   30          4  226525          0                6
# 9756   12882   24          4  186666         15               10
# 9757   20015   18          4  148644         11                9
# 9758   41841   60          2  202473          8               11
# 9759   40163   32          4  398988          9               13
# 9760   42505   21          2  218445         15               10
# 9761   26625   33          6  249249          4                3
# 9762   32121   27          4  205440          0                6
# 9763   46852   47          4  104521          8               11
# 9764    8643   31          4  157568         15               10
# 9765     817   21          7  204034         15               10
# 9745             0              40              39
# 9746             0              45              32
# 9747          1887              40              39
# 9748             0              40              39
# 9749             0              40              39
# 9750             0              10              39
# 9751             0              10              39
# 9752             0              45              39
# 9753             0              40              39
# 9754             0              10              39
# 9755             0              40              39
# 9756             0              50              39
# 9757             0              28              39
# 9758             0              40              39
# 9759             0              40              39
# 9760             0              40              26
# 9761             0              50              39
# 9762             0              40              39
# 9763             0              40              39
# 9764             0              40              39
# 9765             0              16              39
# 9766             0              47              39
# 9767             0              40              39
# 9768             0              40              39
#
# [9769 rows x 15 columns]

# %%
clf = RandomForestClassifier()

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size = 0.33,random_state=42)

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import make_scorer
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# %%
best_clf.get_params
# Out:
# <bound method XGBModel.get_params of XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#        colsample_bytree=1, gamma=0, learning_rate=0.1, max_delta_step=0,
#        max_depth=5, min_child_weight=1, missing=None, n_estimators=200,
#        n_jobs=1, nthread=None, objective='binary:logistic', random_state=0,
#        reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=None,
#        silent=True, subsample=1)>

# %%
clf = RandomForestClassifier()        #Initialize the classifier object

parameters = {'n_estimators':[70,100,130],'max_features':['log2'],'n_jobs':[2]}    #Dictionary of parameters

scorer = make_scorer(accuracy_score)         #Initialize the scorer using make_scorer

grid_obj = GridSearchCV(clf,parameters,scoring=scorer)         #Initialize a GridSearchCV object with above parameters,scorer and classifier

grid_fit = grid_obj.fit(X_train,y_train)        #Fit the gridsearch object with X_train,y_train

best_clf = grid_fit.best_estimator_         #Get the best estimator. For this, check documentation of GridSearchCV object

unoptimized_predictions = (clf.fit(X_train, y_train)).predict(X_test)      #Using the unoptimized classifiers, generate predictions
optimized_predictions = best_clf.predict(X_test)        #Same, but use the best estimator

acc_unop = accuracy_score(y_test, unoptimized_predictions)*100       #Calculate accuracy for unoptimized model
acc_op = accuracy_score(y_test, optimized_predictions)*100         #Calculate accuracy for optimized model

print("Accuracy score on unoptimized model:{}".format(acc_unop))
print("Accuracy score on optimized model:{}".format(acc_op))
# Out:
# Accuracy score on unoptimized model:85.4905001938736
# Accuracy score on optimized model:85.97130670802636

# %%
clf = XGBClassifier()        #Initialize the classifier object

parameters = {'n_estimators':[150,200,250],'max_depth':[3,5,6],'learning_rate':[0.1,0.05,0.2],'n_jobs':[2]}    #Dictionary of parameters

scorer = make_scorer(accuracy_score)         #Initialize the scorer using make_scorer

grid_obj = GridSearchCV(clf,parameters,scoring=scorer)         #Initialize a GridSearchCV object with above parameters,scorer and classifier

grid_fit = grid_obj.fit(X_train,y_train)        #Fit the gridsearch object with X_train,y_train

best_clf = grid_fit.best_estimator_         #Get the best estimator. For this, check documentation of GridSearchCV object

unoptimized_predictions = (clf.fit(X_train, y_train)).predict(X_test)      #Using the unoptimized classifiers, generate predictions
optimized_predictions = best_clf.predict(X_test)        #Same, but use the best estimator

acc_unop = accuracy_score(y_test, unoptimized_predictions)*100       #Calculate accuracy for unoptimized model
acc_op = accuracy_score(y_test, optimized_predictions)*100         #Calculate accuracy for optimized model

print("Accuracy score on unoptimized model:{}".format(acc_unop))
print("Accuracy score on optimized model:{}".format(acc_op))

# %%
y_pred = clf.predict(test)

# %%
y_pred = [str(i).upper() for (i) in y_pred]

# %%
ind = test['Sr.No.']

# %%
len(y_pred)
# Out:
# 9769

# %%
sol = pd.DataFrame(data = y_pred, index = ind)

# %%
sol.to_csv('ans.csv')
