# %%
import pandas as pd

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt

from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import AdaBoostClassifier

from sklearn.tree import DecisionTreeClassifier
from sklearn.linear_model import LogisticRegression

from xgboost import XGBClassifier

from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv('Income_Train.csv')
test1  = pd.read_csv('Income_Test.csv')

# %%
df.describe()
# Out:
#              Sr.No.           age        fnlwgt  educational-num  \
# count  39073.000000  39073.000000  3.907300e+04     39073.000000
# mean   24387.500166     38.633379  1.895564e+05        10.085353
# std    14111.135584     13.705528  1.055786e+05         2.573959
# min        0.000000     17.000000  1.376900e+04         1.000000
# 25%    12094.000000     28.000000  1.175090e+05         9.000000
# 50%    24386.000000     37.000000  1.779550e+05        10.000000
# 75%    36627.000000     48.000000  2.369900e+05        12.000000
# max    48839.000000     90.000000  1.490400e+06        16.000000
#
#        capital-gain  capital-loss  hours-per-week  Unnamed: 15
# count  39073.000000  39073.000000    39073.000000          0.0
# mean    1133.790955     87.251606       40.390269          NaN
# std     7770.463461    403.025278       12.365225          NaN
# min        0.000000      0.000000        1.000000          NaN
# 25%        0.000000      0.000000       40.000000          NaN
# 50%        0.000000      0.000000       40.000000          NaN
# 75%        0.000000      0.000000       45.000000          NaN
# max    99999.000000   4356.000000       99.000000          NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39073 entries, 0 to 39072
# Data columns (total 17 columns):
# Sr.No.             39073 non-null int64
# age                39073 non-null int64
# workclass          39073 non-null object
# fnlwgt             39073 non-null int64
# education          39073 non-null object
# educational-num    39073 non-null int64
# marital-status     39073 non-null object
# occupation         39073 non-null object
# relationship       39073 non-null object
# race               39073 non-null object
# gender             39073 non-null object
# capital-gain       39073 non-null int64
# capital-loss       39073 non-null int64
# hours-per-week     39073 non-null int64
# native-country     39073 non-null object
# Unnamed: 15        0 non-null float64
# Prediction         39073 non-null bool
# dtypes: bool(1), float64(1), int64(7), object(8)
# memory usage: 4.8+ MB

# %%
df.drop(['Unnamed: 15'],axis=1,inplace=True)

# %%
df.head()
# Out:
#    Sr.No.  age workclass  fnlwgt     education  educational-num  \
# 0   42575   27   Private  134566       HS-grad                9
# 1    2531   20         ?  175431  Some-college               10
# 2   42008   18   Private   57108          11th                7
# 3   21107   20   Private  147171  Some-college               10
# 4   28313   47   Private  102771       7th-8th                4
#
#        marital-status         occupation   relationship                race  \
# 0       Never-married       Adm-clerical  Not-in-family               White
# 1       Never-married                  ?      Own-child               White
# 2       Never-married              Sales      Own-child               White
# 3       Never-married       Adm-clerical      Unmarried  Asian-Pac-Islander
# 4  Married-civ-spouse  Handlers-cleaners        Husband               White
#
#    gender  capital-gain  capital-loss  hours-per-week native-country  \
# 0    Male             0             0              40  United-States
# 1    Male             0             0              40  United-States
# 2    Male             0             0              16  United-States
# 3  Female             0             0              40        Vietnam
# 4    Male             0             0              40       Portugal
#
#    Prediction
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False

# %%
test.head()
# Out:
#    Sr.No.  age         workclass  fnlwgt     education  educational-num  \
# 0   23509   18           Private  260801       HS-grad                9
# 1   38928   36      Self-emp-inc  183898     Bachelors               13
# 2   23796   29           Private  209934       5th-6th                3
# 3   31209   32           Private  263908     Bachelors               13
# 4   37938   69  Self-emp-not-inc  204645  Some-college               10
#
#        marital-status         occupation   relationship   race gender  \
# 0       Never-married  Handlers-cleaners      Own-child  White   Male
# 1            Divorced              Sales  Not-in-family  White   Male
# 2  Married-civ-spouse      Other-service        Husband  White   Male
# 3  Married-civ-spouse     Prof-specialty        Husband  White   Male
# 4  Married-civ-spouse       Craft-repair        Husband  White   Male
#
#    capital-gain  capital-loss  hours-per-week native-country
# 0             0             0              20  United-States
# 1             0             0              60  United-States
# 2             0             0              40         Mexico
# 3             0             0              40  United-States
# 4          9386             0              72  United-States

# %%
categorical = ['workclass','marital-status','education','race', 'gender','native-country','occupation','relationship']

# %%
from sklearn.preprocessing import LabelEncoder


le = LabelEncoder()
for col in categorical:
    
    le.fit(df[col])
    df[col] = le.transform(df[col])
    test1[col] = le.transform(test1[col])

# %%
to_scale = ['capital-gain','capital-loss']

# %%
from sklearn.preprocessing import RobustScaler

scaler = RobustScaler()

df[to_scale] = scaler.fit_transform(df[to_scale])
test1[to_scale] = scaler.fit_transform(test1[to_scale])

# %%
df.head()
# Out:
#    Sr.No.  age  workclass  fnlwgt  education  educational-num  marital-status  \
# 0   42575   27          4  134566         11                9               4
# 1    2531   20          0  175431         15               10               4
# 2   42008   18          4   57108          1                7               4
# 3   21107   20          4  147171         15               10               4
# 4   28313   47          4  102771          5                4               2
#
#    occupation  relationship  race  gender  capital-gain  capital-loss  \
# 0           1             1     4       1           0.0           0.0
# 1           0             3     4       1           0.0           0.0
# 2          12             3     4       1           0.0           0.0
# 3           1             4     1       0           0.0           0.0
# 4           6             0     4       1           0.0           0.0
#
#    hours-per-week  native-country  Prediction
# 0              40              39       False
# 1              40              39       False
# 2              16              39       False
# 3              40              40       False
# 4              40              32       False

# %%
to_drop = ['native-country','fnlwgt','Sr.No.']

# %%
test.head()
# Out:
#    age  workclass  education  educational-num  marital-status  occupation  \
# 0   18          4         11                9               4           6
# 1   36          5          9               13               0          12
# 2   29          4          4                3               2           8
# 3   32          4          9               13               2          10
# 4   69          6         15               10               2           3
#
#    relationship  race  gender  capital-gain  capital-loss  hours-per-week
# 0             3     4       1      0.000000           0.0              20
# 1             1     4       1      0.000000           0.0              60
# 2             0     4       1      0.000000           0.0              40
# 3             0     4       1      0.000000           0.0              40
# 4             0     4       1      0.093861           0.0              72

# %%
test = test1.drop(to_drop,axis=1)

# %%
to_drop = ['native-country','fnlwgt','Sr.No.','Prediction']
#to_drop = ['Prediction']
X = df.drop(to_drop,axis = 1)

# %%
X
# Out:
#        age  workclass  education  educational-num  marital-status  occupation  \
# 0       27          4         11                9               4           1
# 1       20          0         15               10               4           0
# 2       18          4          1                7               4          12
# 3       20          4         15               10               4           1
# 4       47          4          5                4               2           6
# 5       41          0          9               13               2           0
# 6       43          4          6                5               0          14
# 7       58          4         11                9               2          12
# 8       39          4         11                9               2           7
# 9       38          6         11                9               2           3
# 10      17          0          1                7               6           0
# 11      38          4          9               13               0          12
# 12      39          4         12               14               2           4
# 13      56          4         11                9               6           7
# 14      72          0         11                9               2           0
# 15      54          4         11                9               2           3
# 16      35          4          9               13               4           1
# 17      30          1         15               10               0           4
# 18      40          4         11                9               2           1
# 19      27          1          8               11               2           1
# 20      38          2         15               10               2           8
# 21      29          2         15               10               0           1
# 22      22          0         15               10               4           0
# 23      30          4          7               12               4           8
# 24      34          4         11                9               2          12
# 25      27          2         11                9               4           5
# 26      27          4         15               10               4           8
# 27      45          6         14               15               2          10
# 28      64          6         10               16               2           4
# 29      41          4         15               10               2          12
# ...    ...        ...        ...              ...             ...         ...
# 39043   30          4         15               10               5           1
# 39044   28          4          9               13               4          11
# 39045   58          4          5                4               2           5
# 39046   33          4          9               13               2           4
# 39047   34          4          2                8               2           3
# 39048   33          4         15               10               2          12
# 39049   18          4          1                7               4           3
# 39050   27          4         11                9               2           6
# 39051   36          4          9               13               5           8
# 39052   45          4          9               13               4          10
# 39053   35          4          9               13               3          10
# 39054   18          4         15               10               4          12
# 39055   46          4          9               13               2           4
# 39056   21          4         11                9               4           3
# 39057   34          4         11                9               4          12
# 39058   41          4         11                9               2           3
# 39059   31          4         11                9               4           6
# 39060   67          6         15               10               2           5
# 39061   29          4         11                9               4          13
# 39062   42          7         15               10               2          11
# 39063   40          4         11                9               5           8
# 39064   20          4          7               12               4           8
# 39065   47          6          9               13               4           3
# 39066   48          4         15               10               0           7
# 39067   47          6         11                9               2           5
# 39068   28          4          2                8               4          14
# 39069   28          4          9               13               2           4
# 39070   21          2         15               10               4           1
# 39071   31          4         11                9               2           3
# 39072   31          4         11                9               2           4
#
#        relationship  race  gender  capital-gain  capital-loss  hours-per-week
# 0                 1     4       1           0.0           0.0              40
# 1                 3     4       1           0.0           0.0              40
# 2                 3     4       1           0.0           0.0              16
# 3                 4     1       0           0.0           0.0              40
# 4                 0     4       1           0.0           0.0              40
# 5                 5     1       0           0.0           0.0               5
# 6                 1     2       1           0.0           0.0              40
# 7                 0     4       1           0.0           0.0              40
# 8                 0     4       1           0.0           0.0              40
# 9                 0     4       1           0.0           0.0              47
# 10                3     4       1           0.0           0.0              40
# 11                1     4       0           0.0           0.0              70
# 12                0     4       1           0.0           0.0              40
# 13                1     2       0           0.0           0.0              40
# 14                0     4       1           0.0           0.0              32
# 15                0     4       1           0.0        1628.0              40
# 16                3     4       0           0.0           0.0              40
# 17                1     2       1           0.0           0.0              40
# 18                5     4       0           0.0           0.0              46
# 19                0     4       1        7298.0           0.0              50
# 20                0     4       1           0.0           0.0              40
# 21                4     4       0           0.0           0.0              40
# 22                3     4       1           0.0        1602.0               8
# 23                2     1       1           0.0           0.0              40
# 24                0     4       1           0.0           0.0              45
# 25                3     0       1           0.0           0.0              60
# 26                3     4       0           0.0           0.0              30
# 27                0     4       1        7298.0           0.0              60
# 28                0     4       1           0.0           0.0              25
# 29                0     4       1           0.0           0.0              50
# ...             ...   ...     ...           ...           ...             ...
# 39043             4     2       0           0.0           0.0              40
# 39044             1     4       0           0.0           0.0              40
# 39045             0     4       1           0.0           0.0              50
# 39046             0     4       1           0.0           0.0              45
# 39047             0     4       1           0.0           0.0              40
# 39048             0     4       1           0.0           0.0              40
# 39049             3     4       1           0.0           0.0               5
# 39050             0     4       1           0.0           0.0              62
# 39051             4     2       0           0.0           0.0              35
# 39052             1     4       0           0.0           0.0              40
# 39053             1     1       0           0.0           0.0              40
# 39054             3     4       0           0.0           0.0              25
# 39055             0     4       1        7298.0           0.0              50
# 39056             1     4       0           0.0           0.0              30
# 39057             1     4       1           0.0           0.0              50
# 39058             0     4       1        7688.0           0.0              42
# 39059             2     2       1           0.0           0.0              40
# 39060             0     4       1           0.0           0.0              44
# 39061             3     4       1           0.0           0.0              40
# 39062             0     2       1           0.0           0.0              48
# 39063             4     4       0           0.0           0.0              47
# 39064             1     4       0           0.0           0.0              40
# 39065             1     4       0           0.0           0.0              40
# 39066             4     4       1           0.0           0.0              40
# 39067             0     4       1        3103.0           0.0              60
# 39068             1     4       1           0.0           0.0              50
# 39069             0     4       1           0.0           0.0              50
# 39070             4     4       1           0.0           0.0              36
# 39071             0     4       1           0.0           0.0              40
# 39072             5     4       0           0.0           0.0              40
#
# [39073 rows x 12 columns]

# %%
import seaborn as sns
# Fetature correlations
# Compute the correlation matrix
corr = df.corr()

# Generate a mask for the upper triangle
mask = np.zeros_like(corr, dtype=np.bool)
mask[np.triu_indices_from(mask)] = True

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(11, 9))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(220, 10, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr, mask=mask, cmap=cmap, vmax=.3, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})

plt.show()

# %%
y = df['Prediction']

# %%
test
# Out:
#       age  workclass  education  educational-num  marital-status  occupation  \
# 0      18          4         11                9               4           6
# 1      36          5          9               13               0          12
# 2      29          4          4                3               2           8
# 3      32          4          9               13               2          10
# 4      69          6         15               10               2           3
# 5      56          1         12               14               0           1
# 6      47          4         15               10               4           8
# 7      58          4          9               13               0          12
# 8      23          4         11                9               4          12
# 9      59          6         11                9               2           4
# 10     21          4          7               12               4           8
# 11     30          4          9               13               4          12
# 12     39          4         11                9               4           3
# 13     37          4         11                9               2          14
# 14     48          4          9               13               4           8
# 15     56          4         11                9               2           3
# 16     27          4         11                9               2          12
# 17     45          4         15               10               2           7
# 18     30          1         11                9               2           2
# 19     54          0         15               10               2           0
# 20     33          4          9               13               2          10
# 21     31          4         15               10               4           1
# 22     38          4         11                9               2           1
# 23     37          2         15               10               0           1
# 24     25          4          9               13               4           4
# 25     25          4         11                9               2          12
# 26     21          4         15               10               4          12
# 27     34          4          9               13               2          12
# 28     17          4          1                7               4          12
# 29     26          6         11                9               2           1
# ...   ...        ...        ...              ...             ...         ...
# 9739   43          1          9               13               2           1
# 9740   21          4         15               10               4          11
# 9741   28          4         11                9               4          14
# 9742   30          4         11                9               2          13
# 9743   38          4         11                9               4           3
# 9744   37          4         15               10               0           8
# 9745   45          2          6                5               4           8
# 9746   34          4         11                9               5           3
# 9747   44          1          9               13               2          10
# 9748   36          4          2                8               2          14
# 9749   26          4         11                9               4           6
# 9750   59          4         12               14               2          10
# 9751   69          6          5                4               4           5
# 9752   25          4         15               10               2          12
# 9753   38          1          9               13               2          10
# 9754   57          4         15               10               0           4
# 9755   30          4          0                6               0          14
# 9756   24          4         15               10               2           3
# 9757   18          4         11                9               4          12
# 9758   60          2          8               11               2           8
# 9759   32          4          9               13               4           4
# 9760   21          2         15               10               4           1
# 9761   33          6          4                3               2           3
# 9762   27          4          0                6               2           7
# 9763   47          4          8               11               2          10
# 9764   31          4         15               10               4           1
# 9765   21          7         15               10               4           8
# 9766   51          4         12               14               2          10
# 9767   29          4         15               10               4           1
# 9768   27          4          1                7               2           6
#
#       relationship  race  gender  capital-gain  capital-loss  hours-per-week
# 0                3     4       1      0.000000      0.000000              20
# 1                1     4       1      0.000000      0.000000              60
# 2                0     4       1      0.000000      0.000000              40
# 3                0     4       1      0.000000      0.000000              40
# 4                0     4       1      0.093861      0.000000              72
# 5                4     4       0      0.000000      0.000000              40
# 6                3     4       1      0.000000      0.000000              40
# 7                1     4       1      0.000000      0.000000              50
# 8                1     4       0      0.000000      0.000000              40
# 9                0     4       1      0.000000      0.000000              40
# 10               3     4       1      0.000000      0.000000              40
# 11               1     4       0      0.000000      0.000000              40
# 12               1     4       1      0.000000      0.000000              60
# 13               0     4       1      0.000000      0.383838              60
# 14               4     1       0      0.000000      0.000000              40
# 15               0     4       1      0.000000      0.000000              40
# 16               0     4       1      0.000000      0.000000              50
# 17               0     4       1      0.000000      0.000000              44
# 18               2     0       1      0.000000      0.000000              48
# 19               0     1       1      0.000000      0.000000              60
# 20               0     4       1      0.000000      0.000000              40
# 21               1     4       0      0.000000      0.000000              40
# 22               0     4       1      0.000000      0.000000              40
# 23               1     4       0      0.000000      0.000000              44
# 24               1     4       0      0.000000      0.000000              40
# 25               0     4       1      0.000000      0.000000              30
# 26               3     4       1      0.000000      0.000000              20
# 27               0     4       1      0.150242      0.000000              40
# 28               3     4       0      0.000000      0.000000              14
# 29               0     4       1      0.000000      0.000000              40
# ...            ...   ...     ...           ...           ...             ...
# 9739             0     4       1      0.072981      0.000000              40
# 9740             3     4       1      0.029070      0.000000              30
# 9741             3     4       1      0.000000      0.000000              40
# 9742             0     4       1      0.000000      0.000000              40
# 9743             1     4       1      0.000000      0.000000              40
# 9744             4     4       0      0.000000      0.000000              25
# 9745             3     4       1      0.000000      0.000000              40
# 9746             1     4       1      0.000000      0.000000              45
# 9747             0     4       1      0.000000      0.433196              40
# 9748             0     4       1      0.000000      0.000000              40
# 9749             1     4       1      0.000000      0.000000              40
# 9750             5     4       0      0.000000      0.000000              10
# 9751             2     4       1      0.018480      0.000000              10
# 9752             0     2       1      0.000000      0.000000              45
# 9753             0     4       1      0.040640      0.000000              40
# 9754             2     4       0      0.005940      0.000000              10
# 9755             3     4       1      0.000000      0.000000              40
# 9756             0     4       1      0.000000      0.000000              50
# 9757             3     4       0      0.000000      0.000000              28
# 9758             0     4       1      0.000000      0.000000              40
# 9759             1     4       1      0.000000      0.000000              40
# 9760             3     4       0      0.000000      0.000000              40
# 9761             0     4       1      0.000000      0.000000              50
# 9762             0     4       1      0.000000      0.000000              40
# 9763             0     4       1      0.000000      0.000000              40
# 9764             1     4       1      0.000000      0.000000              40
# 9765             1     4       0      0.000000      0.000000              16
# 9766             0     4       1      0.000000      0.000000              47
# 9767             2     2       0      0.000000      0.000000              40
# 9768             0     4       1      0.039420      0.000000              40
#
# [9769 rows x 12 columns]

# %%
clf = RandomForestClassifier()

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size = 0.33,random_state=42)

# %%
X_train
# Out:
#        age  workclass  education  educational-num  marital-status  occupation  \
# 22105   23          4          8               11               4          10
# 9158    35          4         11                9               2          14
# 27103   37          2          8               11               4           1
# 8390    38          4         11                9               4           7
# 17492   35          7         15               10               2           7
# 27374   35          6          9               13               2          12
# 22108   23          4         15               10               4          10
# 37988   24          2          7               12               2           8
# 27104   39          4         13                1               4           8
# 19919   60          4         15               10               2          11
# 28907   50          6         11                9               2          12
# 23438   42          4         15               10               4          12
# 5816    32          4          9               13               4           4
# 12168   23          4         11                9               4           1
# 16083   42          2          9               13               5           4
# 11518   36          4          9               13               2          12
# 8253    31          4         11                9               2           1
# 10740   61          7         14               15               2          10
# 19126   44          4         11                9               2          14
# 20223   34          4         11                9               4           7
# 7693    64          2          0                6               2           7
# 34594   28          2         15               10               2          11
# 9006    59          4         15               10               4           1
# 32639   43          4         12               14               0           4
# 4007    37          4         12               14               0           4
# 22444   34          4         11                9               4           1
# 6359    60          0          5                4               2           0
# 38721   33          4         12               14               2          10
# 15324   62          4         11                9               6           1
# 3277    32          4         15               10               2           4
# ...    ...        ...        ...              ...             ...         ...
# 28192   50          4          5                4               0           3
# 31749   40          2         15               10               2           4
# 16198   50          4          9               13               0          12
# 17027   35          2          9               13               4          10
# 36049   54          2         12               14               0          10
# 19972   17          4          0                6               4          12
# 29901   18          4          1                7               2           8
# 11187   39          4          9               13               0          10
# 29396   31          2          9               13               0          10
# 27802   22          4          0                6               2           7
# 27055   48          6          9               13               2          10
# 21911   62          2         12               14               4          10
# 32044   21          7         15               10               4           8
# 32669   49          2         11                9               4           3
# 31093   44          4         15               10               2          13
# 11535   39          4         15               10               5           7
# 26390   24          4         11                9               4           6
# 26903   23          4         11                9               4           3
# 18203   56          2         11                9               2          14
# 28013   37          4          8               11               5           3
# 31489   23          4          9               13               4          10
# 12308   47          5          9               13               2          10
# 9308    57          1          9               13               2          13
# 14835   33          4          4                3               4           7
# 22694   41          4         15               10               2           5
# 17765   37          4         11                9               2           8
# 15883   18          2          0                6               4          11
# 30455   47          4         15               10               2          10
# 11583   43          4          9               13               5          10
# 19541   45          6          9               13               2           4
#
#        relationship  race  gender  capital-gain  capital-loss  hours-per-week
# 22105             3     1       1      0.000000      0.000000              40
# 9158              5     4       0      0.000000      0.000000              48
# 27103             1     4       0      0.000000      0.000000              43
# 8390              1     4       1      0.000000      0.000000              40
# 17492             0     4       1      0.000000      0.000000              50
# 27374             0     4       1      0.000000      0.000000              60
# 22108             1     4       1      0.000000      0.000000              20
# 37988             5     4       0      0.000000      0.000000              40
# 27104             1     4       0      0.000000      0.000000              12
# 19919             0     4       1      0.000000      0.000000              38
# 28907             0     2       1      0.000000      0.000000              40
# 23438             1     4       1      0.000000      0.000000              45
# 5816              1     4       0      0.000000      0.000000              45
# 12168             4     4       0      0.000000      0.000000              40
# 16083             1     4       1      0.000000      0.000000              45
# 11518             0     4       1      0.000000      0.436639              40
# 8253              0     4       1      0.000000      0.000000              40
# 10740             0     4       1      0.000000      0.436639              40
# 19126             0     0       1      0.000000      0.000000              40
# 20223             1     4       1      0.044160      0.000000              30
# 7693              5     4       1      0.000000      0.000000              40
# 34594             0     4       1      0.000000      0.000000              40
# 9006              4     4       0      0.000000      0.000000              40
# 32639             1     4       0      0.000000      0.000000              38
# 4007              1     4       1      0.000000      0.000000              65
# 22444             3     4       1      0.000000      0.000000              40
# 6359              0     4       1      0.000000      0.000000              40
# 38721             0     4       1      0.150242      0.000000              40
# 15324             1     4       0      0.000000      0.000000              32
# 3277              0     4       1      0.000000      0.000000              40
# ...             ...   ...     ...           ...           ...             ...
# 28192             1     4       0      0.000000      0.000000              30
# 31749             0     4       1      0.000000      0.000000              42
# 16198             4     2       1      0.000000      0.000000              40
# 17027             1     4       0      0.000000      0.430670              45
# 36049             1     4       0      0.000000      0.000000              40
# 19972             3     4       0      0.000000      0.000000              16
# 29901             0     4       1      0.000000      0.000000              35
# 11187             1     4       0      0.000000      0.000000              36
# 29396             1     4       0      0.000000      0.000000              40
# 27802             5     4       0      0.000000      0.000000              40
# 27055             5     4       0      0.000000      0.000000              20
# 21911             1     4       0      0.086141      0.000000              45
# 32044             3     4       0      0.000000      0.000000              14
# 32669             1     4       1      0.000000      0.000000              50
# 31093             0     4       1      0.000000      0.000000              40
# 11535             3     4       1      0.000000      0.000000              40
# 26390             3     4       1      0.000000      0.000000              30
# 26903             1     4       1      0.000000      0.000000              40
# 18203             0     4       1      0.000000      0.000000              40
# 28013             1     4       0      0.000000      0.000000              40
# 31489             1     4       1      0.000000      0.000000              40
# 12308             0     4       1      0.000000      0.000000              60
# 9308              0     4       1      0.000000      0.000000              48
# 14835             1     4       1      0.000000      0.000000              35
# 22694             0     4       1      0.000000      0.000000              16
# 17765             5     1       0      0.000000      0.000000              60
# 15883             3     4       0      0.000000      0.000000               6
# 30455             0     4       1      0.000000      0.000000              40
# 11583             4     4       0      0.000000      0.000000              40
# 19541             5     1       0      0.000000      0.000000              48
#
# [26178 rows x 12 columns]

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import make_scorer
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# %%
best_clf.get_params
# Out:
# <bound method BaseEstimator.get_params of AdaBoostClassifier(algorithm='SAMME.R', base_estimator=None,
#           learning_rate=1.0, n_estimators=600, random_state=None)>

# %%
clf = RandomForestClassifier()        #Initialize the classifier object

parameters = {'n_estimators':[20,30,50,70],'max_features':['log2'],'n_jobs':[2]}    #Dictionary of parameters

scorer = make_scorer(accuracy_score)         #Initialize the scorer using make_scorer

grid_obj = GridSearchCV(clf,parameters,scoring=scorer)         #Initialize a GridSearchCV object with above parameters,scorer and classifier

grid_fit = grid_obj.fit(X_train,y_train)        #Fit the gridsearch object with X_train,y_train

best_clf = grid_fit.best_estimator_         #Get the best estimator. For this, check documentation of GridSearchCV object

unoptimized_predictions = (clf.fit(X_train, y_train)).predict(X_test)      #Using the unoptimized classifiers, generate predictions
optimized_predictions = best_clf.predict(X_test)        #Same, but use the best estimator

acc_unop = accuracy_score(y_test, unoptimized_predictions)*100       #Calculate accuracy for unoptimized model
acc_op = accuracy_score(y_test, optimized_predictions)*100         #Calculate accuracy for optimized model

print("Accuracy score on unoptimized model:{}".format(acc_unop))
print("Accuracy score on optimized model:{}".format(acc_op))
# Out:
# Accuracy score on unoptimized model:84.43582784024815
# Accuracy score on optimized model:85.0329585110508

# %%
best_clf.get_params
# Out:
# <bound method BaseEstimator.get_params of AdaBoostClassifier(algorithm='SAMME.R', base_estimator=None,
#           learning_rate=1.0, n_estimators=600, random_state=None)>

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
dt = DecisionTreeClassifier()

# %%
clf = AdaBoostClassifier()        #Initialize the classifier object

parameters = {'n_estimators':[300]}#Dictionary of parameters

scorer = make_scorer(accuracy_score)         #Initialize the scorer using make_scorer

grid_obj = GridSearchCV(clf,parameters,scoring=scorer)         #Initialize a GridSearchCV object with above parameters,scorer and classifier

grid_fit = grid_obj.fit(X_train,y_train)        #Fit the gridsearch object with X_train,y_train

best_clf = grid_fit.best_estimator_         #Get the best estimator. For this, check documentation of GridSearchCV object

unoptimized_predictions = (clf.fit(X_train, y_train)).predict(X_test)      #Using the unoptimized classifiers, generate predictions
optimized_predictions = best_clf.predict(X_test)        #Same, but use the best estimator

acc_unop = accuracy_score(y_test, unoptimized_predictions)*100       #Calculate accuracy for unoptimized model
acc_op = accuracy_score(y_test, optimized_predictions)*100         #Calculate accuracy for optimized model

print("Accuracy score on unoptimized model:{}".format(acc_unop))
print("Accuracy score on optimized model:{}".format(acc_op))

# %%
best_clf.fit(X,y)
# Out:
# AdaBoostClassifier(algorithm='SAMME.R', base_estimator=None,
#           learning_rate=1.0, n_estimators=300, random_state=None)

# %%
y_pred = best_clf.predict(test)

# %%
y_pred = [str(i).upper() for (i) in y_pred]

# %%
ind = test1['Sr.No.']

# %%
len(y_pred)
# Out:
# 9769

# %%
sol = pd.DataFrame(data = y_pred, index = ind)

# %%
sol.to_csv('ans.csv')
